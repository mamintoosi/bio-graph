# %% [markdown]
# ## M. Amintoosi
# ## کاوش الگوهای پرتکرار
# استخراج قوانین انجمنی

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# min_count = 4, minFreq = 7, AP@k hybrid was better
#
# در روش متابولیت به عنوان نود، جواب خوبی نگرفتم
# البته نمی دانم که در جدول
# LR
# متابولیتی داریم که در جدول
# AC
# نباشه

# %%
# %%time
# %run main.py
# Out:
#   1%|          | 747/70225 [00:00<00:09, 7457.95it/s]
# Number of unique elements of columns: 472
# Corpus size:  (265, 472)
# Computing Adjacency Matrix...
# 100%|██████████| 70225/70225 [00:08<00:00, 8194.82it/s]
# Computing the largest connected graph...
#   0%|          | 0/5 [00:00<?, ?it/s]
# Number of nodes sub graph: 251
# Computing features...
#  20%|██        | 1/5 [00:01<00:04,  1.15s/it]
#   2%|▏         | 4/206 [00:00<00:05, 37.87it/s]
# Number of unique elements of columns: 416
# Corpus size:  (251, 416)
# Number of Freq. Itemsets: 206
# Computing adjacency Graphs by Frequently Itemsets...
# 100%|██████████| 206/206 [00:05<00:00, 41.01it/s]
# Correlation of degree and degree_fim: 0.32853001842295154
# CPU times: user 20.8 s, sys: 375 ms, total: 21.1 s
# Wall time: 21.3 s

# %%
# node_names
gf_fim_df_sorted
# ['degree_cent']-gf_fim_df_sorted['degree_fim']
s1 = gf_fim_df_sorted['degree_cent']
s2 = gf_fim_df_sorted['degree_fim']
print(s1.corr(s2))#, method=histogram_intersection))
# Out:
# 0.32853001842295154

# %%
# from bio_graph_utils import *
# df_2_col_to_spread('AC','Plant')
# df_2_col_to_spread('LR','Plant')
# Out:
# 100%|██████████| 3251/3251 [00:32<00:00, 100.03it/s]
# 100%|██████████| 403/403 [00:06<00:00, 60.17it/s]

# %%
df
# Out:
#     Arabidopsis thaliana  Begonia nantoensis  Cucumis sativus  Pisum sativum   \
# 0                   0.00                0.00             0.00            0.00
# 1                   1.00                1.00             1.00            2.00
# 2                   2.00                2.00             9.00           14.00
# 3                   3.00                9.00            14.00           18.00
# 4                   4.00                 nan            15.00             nan
# 5                   5.00                 nan              nan             nan
# 6                   6.00                 nan              nan             nan
# 7                   7.00                 nan              nan             nan
# 8                   8.00                 nan              nan             nan
# 9                   9.00                 nan              nan             nan
# 10                 10.00                 nan              nan             nan
# 11                 11.00                 nan              nan             nan
# 12                 12.00                 nan              nan             nan
# 13                 13.00                 nan              nan             nan
#
#     Annona muricata  Calligonum leucocladum  Chamaecyparis formosensis  \
# 0              1.00                    1.00                       1.00
# 1             21.00                    2.00                       6.00
# 2             22.00                    6.00                       7.00
# 3             23.00                   12.00                      37.00
# 4             24.00                   16.00                      38.00
# 5             25.00                   36.00                      39.00
# 6             26.00                     nan                        nan
# 7             27.00                     nan                        nan
# 8             28.00                     nan                        nan
# 9             29.00                     nan                        nan
# 10            30.00                     nan                        nan
# 11            31.00                     nan                        nan
# 12            32.00                     nan                        nan
# 13            33.00                     nan                        nan
#
#     Citrus limon   Epimedium sagittatum   Falcaria vulgaris  ...  \
# 0            1.00                   1.00               1.00  ...
# 1            2.00                  10.00               2.00  ...
# 2            6.00                  16.00               6.00  ...
# 3            9.00                  36.00              16.00  ...
# 4           40.00                    nan              45.00  ...
# 5           41.00                    nan                nan  ...
# 6           42.00                    nan                nan  ...
# 7             nan                    nan                nan  ...
# 8             nan                    nan                nan  ...
# 9             nan                    nan                nan  ...
# 10            nan                    nan                nan  ...
# 11            nan                    nan                nan  ...
# 12            nan                    nan                nan  ...
# 13            nan                    nan                nan  ...
#
#     Isodon rubescens  Syzygium formosanum  Glycyrrhiza inflata  \
# 0             563.00                 7.00                11.00
# 1             564.00                62.00               200.00
# 2             568.00                68.00               201.00
# 3             569.00               135.00               202.00
# 4             570.00                  nan               203.00
# 5                nan                  nan               577.00
# 6                nan                  nan                  nan
# 7                nan                  nan                  nan
# 8                nan                  nan                  nan
# 9                nan                  nan                  nan
# 10               nan                  nan                  nan
# 11               nan                  nan                  nan
# 12               nan                  nan                  nan
# 13               nan                  nan                  nan
#
#     Diospyros eriantha  Diospyros lotus   Pongamia pinnata  \
# 0                62.00             62.00             62.00
# 1                68.00             68.00             68.00
# 2               135.00            135.00            580.00
# 3               527.00            527.00            581.00
# 4                  nan               nan               nan
# 5                  nan               nan               nan
# 6                  nan               nan               nan
# 7                  nan               nan               nan
# 8                  nan               nan               nan
# 9                  nan               nan               nan
# 10                 nan               nan               nan
# 11                 nan               nan               nan
# 12                 nan               nan               nan
# 13                 nan               nan               nan
#
#     Calophyllum blancoi  Viburnum luzonicum  Isodon melissoides  \
# 0                220.00              624.00              590.00
# 1                537.00              625.00              634.00
# 2                599.00              626.00              635.00
# 3                600.00              627.00              636.00
# 4                601.00              628.00                 nan
# 5                   nan              629.00                 nan
# 6                   nan              630.00                 nan
# 7                   nan              631.00                 nan
# 8                   nan              632.00                 nan
# 9                   nan              633.00                 nan
# 10                  nan                 nan                 nan
# 11                  nan                 nan                 nan
# 12                  nan                 nan                 nan
# 13                  nan                 nan                 nan
#
#     Isodon eriocalyx
# 0             644.00
# 1             645.00
# 2             646.00
# 3             647.00
# 4             648.00
# 5                nan
# 6                nan
# 7                nan
# 8                nan
# 9                nan
# 10               nan
# 11               nan
# 12               nan
# 13               nan
#
# [14 rows x 265 columns]

# %%
set(df.keys().values) - set(df_subG.keys().values)
# Out:
# {'Ammocharis coranica ',
#  'Catharanthus roseus ',
#  'Cneorum pulverulentum',
#  'Cneorum tricoccum',
#  'Isodon eriocalyx',
#  'Isodon japonica',
#  'Isodon melissoides',
#  'Isodon rubescens',
#  'Kadsura interior',
#  'Lycoris radiata ',
#  'Mallotus japonicus',
#  'Maytenus buchananii ',
#  'Viburnum luzonicum',
#  'Vinca rosea'}

# %%
df_subG
# Out:
#     Arabidopsis thaliana  Begonia nantoensis  Cucumis sativus  Pisum sativum   \
# 0                   0.00                0.00             0.00            0.00
# 1                   1.00                1.00             1.00            2.00
# 2                   2.00                2.00             9.00           14.00
# 3                   3.00                9.00            14.00           18.00
# 4                   4.00                 nan            15.00             nan
# 5                   5.00                 nan              nan             nan
# 6                   6.00                 nan              nan             nan
# 7                   7.00                 nan              nan             nan
# 8                   8.00                 nan              nan             nan
# 9                   9.00                 nan              nan             nan
# 10                 10.00                 nan              nan             nan
# 11                 11.00                 nan              nan             nan
# 12                 12.00                 nan              nan             nan
# 13                 13.00                 nan              nan             nan
#
#     Annona muricata  Calligonum leucocladum  Chamaecyparis formosensis  \
# 0              1.00                    1.00                       1.00
# 1             21.00                    2.00                       6.00
# 2             22.00                    6.00                       7.00
# 3             23.00                   12.00                      37.00
# 4             24.00                   16.00                      38.00
# 5             25.00                   36.00                      39.00
# 6             26.00                     nan                        nan
# 7             27.00                     nan                        nan
# 8             28.00                     nan                        nan
# 9             29.00                     nan                        nan
# 10            30.00                     nan                        nan
# 11            31.00                     nan                        nan
# 12            32.00                     nan                        nan
# 13            33.00                     nan                        nan
#
#     Citrus limon   Epimedium sagittatum   Falcaria vulgaris  ...  \
# 0            1.00                   1.00               1.00  ...
# 1            2.00                  10.00               2.00  ...
# 2            6.00                  16.00               6.00  ...
# 3            9.00                  36.00              16.00  ...
# 4           40.00                    nan              45.00  ...
# 5           41.00                    nan                nan  ...
# 6           42.00                    nan                nan  ...
# 7             nan                    nan                nan  ...
# 8             nan                    nan                nan  ...
# 9             nan                    nan                nan  ...
# 10            nan                    nan                nan  ...
# 11            nan                    nan                nan  ...
# 12            nan                    nan                nan  ...
# 13            nan                    nan                nan  ...
#
#     Garcinia linii  Mammea africana   Mesua ferrea  Saussurea lappa  \
# 0           216.00            216.00        216.00            68.00
# 1           217.00            217.00        217.00           135.00
# 2           514.00            543.00        545.00           513.00
# 3           538.00            544.00        546.00           555.00
# 4           539.00               nan           nan              nan
# 5           540.00               nan           nan              nan
# 6           541.00               nan           nan              nan
# 7           542.00               nan           nan              nan
# 8              nan               nan           nan              nan
# 9              nan               nan           nan              nan
# 10             nan               nan           nan              nan
# 11             nan               nan           nan              nan
# 12             nan               nan           nan              nan
# 13             nan               nan           nan              nan
#
#     Syzygium formosanum  Glycyrrhiza inflata  Diospyros eriantha  \
# 0                  7.00                11.00               62.00
# 1                 62.00               200.00               68.00
# 2                 68.00               201.00              135.00
# 3                135.00               202.00              527.00
# 4                   nan               203.00                 nan
# 5                   nan               577.00                 nan
# 6                   nan                  nan                 nan
# 7                   nan                  nan                 nan
# 8                   nan                  nan                 nan
# 9                   nan                  nan                 nan
# 10                  nan                  nan                 nan
# 11                  nan                  nan                 nan
# 12                  nan                  nan                 nan
# 13                  nan                  nan                 nan
#
#     Diospyros lotus   Pongamia pinnata  Calophyllum blancoi
# 0              62.00             62.00               220.00
# 1              68.00             68.00               537.00
# 2             135.00            580.00               599.00
# 3             527.00            581.00               600.00
# 4                nan               nan               601.00
# 5                nan               nan                  nan
# 6                nan               nan                  nan
# 7                nan               nan                  nan
# 8                nan               nan                  nan
# 9                nan               nan                  nan
# 10               nan               nan                  nan
# 11               nan               nan                  nan
# 12               nan               nan                  nan
# 13               nan               nan                  nan
#
# [14 rows x 251 columns]

# %%
# df_AC = pd.read_excel('data/AC_met_plant_spread.xlsx', engine="openpyxl") 
# G=nx.from_pandas_adjacency(df_AC)
# conComp = list(nx.connected_components(G))
# n_con_comp = [len(x) for x in conComp]
# print(n_con_comp)

G2 = nx.from_numpy_matrix(G) 
# nx.draw(G2)
print(G2.nodes())
conComp = list(nx.connected_components(G2))
n_con_comp = [len(x) for x in conComp]
print(n_con_comp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-66a77bbabd5e> in <module>
#       1 # df_AC = pd.read_excel('data/AC_met_plant_spread.xlsx', engine="openpyxl")
#       2 # G=nx.from_pandas_adjacency(df_AC)
# ----> 3 conComp = list(nx.connected_components(G))
#       4 n_con_comp = [len(x) for x in conComp]
#       5 print(n_con_comp)
#
# <decorator-gen-294> in connected_components(G)
#
# ~/anaconda3/lib/python3.7/site-packages/networkx/utils/decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      59         graph = args[0]
#      60         terms = {
# ---> 61             "directed": graph.is_directed(),
#      62             "undirected": not graph.is_directed(),
#      63             "multigraph": graph.is_multigraph(),
#
# AttributeError: 'numpy.ndarray' object has no attribute 'is_directed'
