# %% [markdown]
# ## M. Amintoosi
# ## کاوش الگوهای پرتکرار
# استخراج قوانین انجمنی

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip3 install Orange3-Associate -q
# !pip install pyvis
# !pip install  ml_metrics -q
# !pip install  recmetrics -q
# !pip install funcsigs -q
# Out:
#      |████████████████████████████████| 532kB 9.3MB/s
#      |████████████████████████████████| 2.7MB 13.7MB/s
#      |████████████████████████████████| 235kB 42.7MB/s
#      |████████████████████████████████| 51kB 9.9MB/s
#      |████████████████████████████████| 2.3MB 43.5MB/s
#      |████████████████████████████████| 829kB 45.6MB/s
#      |████████████████████████████████| 460kB 64.8MB/s
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/xlsxwriter/
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /packages/6b/41/bf1aae04932d1eaffee1fc5f8b38ca47bbbf07d765129539bc4bcce1ce0c/XlsxWriter-1.3.7-py2.py3-none-any.whl
# ...

# %%
# cat /usr/local/lib/python3.6/dist-packages/recmetrics/plots.py

# %%
cd /content/drive/My Drive/colabs/CoWork/Kohan
# Out:
# /content/drive/My Drive/colabs/CoWork/Kohan

# %%
# !cp plots.py /usr/local/lib/python3.6/dist-packages/recmetrics/

# %%
# %%time
# %run main.py
# Out:
# Table info:  (5392, 2)
# Number of nodes in main file:  3251
# Number of nodes after prunning those are below min count=3 is: 502
#   0%|          | 0/5 [00:00<?, ?it/s]
# Computing the largest connected graph...
#
# Number of sub graph nodes: 482
# Sub graph info:  (482, 502)
# Computing the graph features...
# ...
#   1%|          | 2/269 [00:00<00:13, 19.14it/s]
# Computing frequent itemsets...
#
# Number of Freq. Itemsets: 269
# Computing adjacency Graphs by Frequently Itemsets...
#
# (frozenset({349}), 93)
# (frozenset({348}), 87)
# (frozenset({348, 349}), 72)
#   2%|▏         | 6/269 [00:00<00:13, 18.79it/s]
# (frozenset({268}), 86)
# 100%|██████████| 269/269 [00:12<00:00, 21.58it/s]
# CPU times: user 21.4 s, sys: 237 ms, total: 21.6 s
# Wall time: 21.9 s
